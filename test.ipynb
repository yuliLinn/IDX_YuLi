# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %%
# test test

# %%
7+8
# Out:
# 15

# %%
df = pd.read_csv("CRMLSListing202401.csv")
df
# Out:
#        OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0                90000.0  1075010398                miriamlara03@gmail.com
# 1              1500000.0  1074974457                  janelle@judsonre.com
# 2              1340000.0  1074973329                    haleh360@Gmail.com
# 3              2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 4              3150000.0  1074936537                      anader@dppre.com
# ...                  ...         ...                                   ...
# 27449          2850000.0  1045566949                   rosieteddie@cox.net
# 27450          1668000.0  1044575849              hollybuiRealty@gmail.com
# 27451          1399990.0  1043760653               joe@porchlightsocal.com
# 27452           969900.0  1040857564               homes@efrainachacon.com
# 27453          1849000.0  1040106337             Jason.Daniels@Compass.com
#
# ...
